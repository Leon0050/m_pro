# %%
import torch

# %%
print("PyTorch version:", torch._version_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print("PyTorch version:", torch._version_)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/__init__.py:2688, in __getattr__(name)
#    2685 if name in _lazy_modules:
#    2686     return importlib.import_module(f".{name}", __name__)
# -> 2688 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute '_version_'

# %%
print("PyTorch version:", torch.__version__
     )
# Out:
# PyTorch version: 2.7.1

# %%
x = torch.randn(3,4)

# %%
print("Tensor shape:", x.shape)
# Out:
# Tensor shape: torch.Size([3, 4])

# %%
print("Tensor data type:", x.dtype )
# Out:
# Tensor data type: torch.float32

# %%
print(x)
# Out:
# tensor([[ 0.0455,  0.4614, -0.4655,  0.5167],
#         [ 0.6852,  1.8345,  1.3634,  0.2342],
#         [ 1.0941,  0.8552, -2.0954, -1.0489]])

# %%
y = torch.randn(4,5)
z = torch.matmul(x,y)
c = x @ y
print("矩阵结果是:\n", z)
print("矩阵结果是:\n", c)
# Out:
# 矩阵结果是:
#  tensor([[-0.3745,  0.7203,  0.6504, -0.3762,  0.4499],
#         [-0.4560,  2.2801, -0.3898,  4.1672, -2.2791],
#         [-1.2157,  2.2147, -1.0622, -0.8421,  0.1407]])
# 矩阵结果是:
#  tensor([[-0.3745,  0.7203,  0.6504, -0.3762,  0.4499],
#         [-0.4560,  2.2801, -0.3898,  4.1672, -2.2791],
#         [-1.2157,  2.2147, -1.0622, -0.8421,  0.1407]])
